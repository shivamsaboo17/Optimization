# %%
import numpy as np
import matplotlib.pyplot as plt
from optimizers import *

# %%
# Aim is to solve Ax=b where x is unknown
# This example will be used throughout
A = np.array([[3, 2], [2, 6]])
b = np.array([2, -8])

# %%
A
# Out:
# array([[3, 2],
#        [2, 6]])

# %%
b
# Out:
# array([ 2, -8])

# %%
optimizer = SteepestDescent(A, b)

# %%
x = optimizer.converge(iterations=10)

# %%
x
# Out:
# array([ 2., -2.])

# %%
optimizer.plot_convergence()

# %%
np.linalg.solve(A, b)
# Out:
# array([ 2., -2.])

# %%
optimizer = ConjugateDirection(A, b)

# %%
optimizer.converge()
# Out:
# array([ 2., -2.])

# %%
optimizer.d_list
# Out:
# [array([0, 1]), array([ 1.        , -0.33333333])]

# %%
optimizer.beta_dict
# Out:
# {(1, 0): -0.3333333333333333}

# %%
optimizer.plot_convergence()
